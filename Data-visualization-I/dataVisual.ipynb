# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('./train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.displot(df['Fare'])  # Displot is a function in seaborn that creates a histogram or kernel density estimate (KDE) plot to visualize the distribution of a single variable. It helps to understand the frequency and spread of the data.

# %%
sns.displot(df['Fare'], kde=False, bins=10)  # bins = number of intervals in histogram; kde = smooth density curve (True shows curve, False hides it)

# %%
sns.jointplot(x='Age', y='Fare', data=df) # Jointplot creates a scatter plot of two variables along with their marginal distributions (histograms or KDE plots) to show the relationship between them and their individual distributions.

# %%
sns.pairplot(df) # Pairplot creates a grid of scatter plots for all pairs of numerical variables in the dataset, along with histograms or KDE plots on the diagonal to show the distribution of each variable. It helps to visualize relationships and distributions across multiple variables simultaneously.

# %%
sns.rugplot(df['Fare']) # Rugplot creates a plot that shows the distribution of a single variable by placing small vertical lines (or "rugs") along the x-axis at the positions of the data points. It provides a visual representation of the density of the data and can be used to identify clusters or gaps in the distribution.
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.barplot(x='Sex', y='Fare', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>

# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x='Sex', y='Age', data=df, estimator=np.std) # estimator=np.std calculates the standard deviation of 'Age' for each category
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.countplot(x='Fare', data=df) # Countplot creates a bar plot that shows the count of occurrences for each category in a categorical variable. It is used to visualize the frequency distribution of a categorical variable and can help identify the most common categories or any imbalances in the data.
# Out:
# <Axes: xlabel='Fare', ylabel='count'>

# %%
sns.boxplot(x='Sex', y='Age', data=df) # Boxplot creates a box-and-whisker plot that displays the distribution of a numerical variable (Age) across different categories of a categorical
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x='Sex', y='Age', data=df, hue="Survived") # Boxplot with hue creates a box-and-whisker plot that displays the distribution of a numerical variable (Age) across different categories of a categorical
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.violinplot(x='Sex', y='Age', data=df, hue='Survived') # Violinplot creates a plot that combines a boxplot and a kernel density estimate (KDE) to show the distribution of a numerical variable (Age) across different categories of a categorical
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.histplot(data=df,x='Fare',y='Survived') # Histplot creates a histogram to visualize the distribution of a numerical variable (Fare) and can also show the relationship between that variable and a categorical variable (Survived) using color or hue. It helps to understand how the distribution of Fare varies based on survival status.
# Out:
# <Axes: xlabel='Fare', ylabel='Survived'>
