# %%
# !pip install nltk

# %%
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt_tab')
text='hello mr.Aniket , how are you doing today? the weather is great in here and the city is awesome! you should be here!!'
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['hello mr.Aniket , how are you doing today?', 'the weather is great in here and the city is awesome!', 'you should be here!', '!']
# [nltk_data] Downloading package punkt_tab to /home/vedant/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['hello', 'mr.Aniket', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'the', 'weather', 'is', 'great', 'in', 'here', 'and', 'the', 'city', 'is', 'awesome', '!', 'you', 'should', 'be', 'here', '!', '!']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopWords=set(stopwords.words('english'))
print(stopWords)
# Out:
# {'couldn', "i've", "that'll", "won't", 'then', 've', 'once', 'very', 'are', 'all', 'we', 'who', 'yours', "weren't", 't', 'haven', "he'd", 'just', 'an', 'this', 'myself', 'shouldn', 'such', "couldn't", 'wasn', 'between', "i'd", 'again', 'wouldn', 'most', 'from', 'is', 'yourselves', "shan't", 'through', "wouldn't", 'ours', 'so', 'had', 'did', 'ma', 'their', 'he', 'further', "shouldn't", 'will', 'won', 'below', 'before', 'am', 'y', 'until', 'but', 'hasn', 'over', 'more', 'theirs', 'was', 'or', "it's", 'should', 'if', 'ain', 'weren', "it'll", 'its', 'ourselves', 'hers', "they'll", 'them', 'only', 'him', 'themselves', 'off', 'herself', "we've", 'does', 'each', 'any', 'how', 're', "she'll", 'me', 'of', 'out', "should've", 'with', 'having', 'while', "she's", "they'd", 'our', 'into', 'on', 'm', "aren't", 'own', 'they', "we'll", 'were', 'your', 'don', 'needn', 'hadn', 'both', 'no', 'than', 'against', 'some', 'there', 'during', "he'll", 'aren', 'by', 'few', 'for', 'my', 'do', "wasn't", "mightn
# ...

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_text)
print(fdist)
# Out:
# <FreqDist with 4 samples and 4 outcomes>

# %%
filtered_sent=[]
for w in tokenized_word:
    if w in stopWords:
        filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_word)
print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: ['hello', 'mr.Aniket', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'the', 'weather', 'is', 'great', 'in', 'here', 'and', 'the', 'city', 'is', 'awesome', '!', 'you', 'should', 'be', 'here', '!', '!']
# Filterd Sentence: ['how', 'are', 'you', 'doing', 'the', 'is', 'in', 'here', 'and', 'the', 'is', 'you', 'should', 'be', 'here']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize,word_tokenize

ps=PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))
print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['how', 'are', 'you', 'doing', 'the', 'is', 'in', 'here', 'and', 'the', 'is', 'you', 'should', 'be', 'here']
# Stemmed Sentence: ['how', 'are', 'you', 'do', 'the', 'is', 'in', 'here', 'and', 'the', 'is', 'you', 'should', 'be', 'here']

# %%
from nltk.stem.wordnet import WordNetLemmatizer
import nltk
nltk.download('wordnet')
lem=WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem=PorterStemmer()
# Out:
# [nltk_data] Downloading package wordnet to /home/vedant/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
word = "creating"
print("Lemmatized Word:",lem.lemmatize(word,"v"))
print("Stemmed Word:",stem.stem(word))
# Out:
# Lemmatized Word: create
# Stemmed Word: creat

# %%
sent = "Albert Einstein was born in Ulm, Germany in 1879."
tokens=nltk.word_tokenize(sent)
print(tokens)
# Out:
# ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germany', 'in', '1879', '.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
nltk.pos_tag(tokens)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/vedant/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [('Albert', 'NNP'),
#  ('Einstein', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Ulm', 'NNP'),
#  (',', ','),
#  ('Germany', 'NNP'),
#  ('in', 'IN'),
#  ('1879', 'CD'),
#  ('.', '.')]

# %%
import nltk
import pandas as pd
data=pd.read_csv('./train.tsv' , sep='\t')
data.head()
# Out:
#    PhraseId  ...  Sentiment
# 0         1  ...          1
# 1         2  ...          2
# 2         3  ...          2
# 3         4  ...          2
# 4         5  ...          2
#
# [5 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 156060 entries, 0 to 156059
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   PhraseId    156060 non-null  int64
#  1   SentenceId  156060 non-null  int64
#  2   Phrase      156060 non-null  str
#  3   Sentiment   156060 non-null  int64
# dtypes: int64(3), str(1)
# memory usage: 4.8 MB

# %%
data.Sentiment.value_counts()
# Out:
# Sentiment
# 2    79582
# 3    32927
# 1    27273
# 4     9206
# 0     7072
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
Sentiment_count=data.groupby('Sentiment').count()
plt.bar(Sentiment_count.index.values, Sentiment_count['Phrase'])
plt.xlabel('Review Sentiments')
plt.ylabel('Number of Review')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer

token = RegexpTokenizer(r'[a-zA-Z0-9]+')  # Create tokenizer that keeps only letters and numbers, removes punctuation
cv = CountVectorizer(
    lowercase=True,
    stop_words='english',
    ngram_range=(1,1),
    tokenizer=token.tokenize,
    token_pattern=None
)
text_counts= cv.fit_transform(data['Phrase'])
# Convert text data into numerical word-frequency vectors after tokenizing and removing stopwords

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    text_counts, data['Sentiment'], test_size=0.3, random_state=1)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# MultinomialNB Accuracy: 0.6049169122986885

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer()
text_tf= tf.fit_transform(data['Phrase'])
print(text_tf)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 972099 stored elements and shape (156060, 15240)>
#   Coords	Values
#   (0, 11837)	0.1761994204821687
#   (0, 9227)	0.27061683772839323
#   (0, 4577)	0.278538658922562
#   (0, 3490)	0.2485059095620638
#   (0, 13505)	0.17690005957760713
#   (0, 288)	0.251134096800077
#   (0, 13503)	0.08982508036989033
#   (0, 14871)	0.1354415412970302
#   (0, 7217)	0.17522921677393963
#   (0, 5821)	0.2625302862532789
#   (0, 5323)	0.20344769269023563
#   (0, 5837)	0.22883807138484064
#   (0, 529)	0.1614381914318891
#   (0, 5595)	0.265796263188737
#   (0, 12424)	0.1381592967010513
#   (0, 14888)	0.28701927784529135
#   (0, 9204)	0.19301332592202286
#   (0, 602)	0.26341877863818697
#   (0, 1879)	0.11034437734762885
#   (0, 9085)	0.1898515417082945
#   (0, 593)	0.22068902883834374
#   (0, 13681)	0.07615285026452821
#   (0, 8807)	0.1353879543646446
#   (0, 12857)	0.12785637560254456
#   (1, 11837)	0.29125926935214375
#   :	:
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    text_tf, data['Sentiment'], test_size=0.3, random_state=123)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# MultinomialNB Accuracy: 0.5865265496176684
