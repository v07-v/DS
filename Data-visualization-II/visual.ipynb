# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_csv('./train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.boxplot(x='Gender', y='Age',data=df) #Compares age distribution between male and female
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
# import seaborn as sns
# from seaborn import load_dataset
#titanic dataset
data = pd.read_csv('./train.csv')
#tips dataset
# tips = load_dataset("tips")
sns.boxplot(x='Survived', y ='Fare', data=df) # what this graph signifies is that the people who survived paid more fare than those who did not survive. This could be because the people who paid more fare were in better cabins and had better access to lifeboats, or it could be due to other factors such as age, gender, or class. It is important to note that this graph does not necessarily imply causation, and further analysis would be needed to determine the underlying reasons for this relationship.
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sns.boxplot(x='Gender', y='Age', data=df, hue="Survived") # this graph shows the age distribution of male and female passengers on the Titanic, with a distinction between those who survived and those who did not. The boxplot allows us to compare the age distribution of survivors and non-survivors within each gender. We can see that the age distribution of survivors is generally higher than that of non-survivors, which may suggest that older passengers were more likely to survive. Additionally, we can see that there are more male passengers than female passengers, and that the age distribution of male passengers is wider than that of    female passengers. Overall, this graph provides insights into the relationship between age, gender, and survival on the Titanic.
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>
